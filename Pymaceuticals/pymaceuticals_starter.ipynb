# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
# As observed from the data, Capomulin, Propriva, and Infubinol is very effective in keeping the mice alive.
# The Pie Charts shows that there are more population of male mice(51%) as compared to the  female mice (49%).
# The line graph can show us how the tumor size changes over time depening on the mice.
# The scatter plot lines show the relation with tumor size and the mass of mice. There is a strong correlation of 0.84, which implies that the greater the tumor size, the heavier the mouse.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combined_df = pd.merge(study_results, mouse_metadata, on="Mouse ID")

# Display the data table for preview
combined_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# 3  Female           9          22
# 4  Female           9          22

# %%
# Checking the number of mice.
num_of_mice = len(pd.unique(combined_df["Mouse ID"]))
num_of_mice
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
mice_duplicates = combined_df[combined_df.duplicated()]
mice_duplicates["Mouse ID"]
# Out:
# 861    g989
# Name: Mouse ID, dtype: object

# %%
# Optional: Get all the data for the duplicate mouse ID. 
data_mice_duplicates = combined_df[combined_df["Mouse ID"] == "g989"]
data_mice_duplicates
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = combined_df.drop(labels=(data_mice_duplicates.index))
clean_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# 3  Female           9          22
# 4  Female           9          22

# %%
# Checking the number of mice in the clean DataFrame.
mice_count_clean = len(clean_df["Mouse ID"].unique())
mice_count_clean
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
mean_drug = clean_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
median_drug = clean_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
variance_drug = clean_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
std_drug = clean_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
sem_drug = clean_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()

summary_drug1_df = pd.DataFrame({
    'Mean Tumor Volume': mean_drug,
    'Median Tumor Volume': median_drug,
    'Tumor Volume Variance': variance_drug,
    'Tumor Volume Std. Dev.': std_drug,
    'Tumor Volume Std. Err.': sem_drug
})

summary_drug1_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
summary_drug2_df = clean_df.groupby(["Drug Regimen"]).agg({"Tumor Volume (mm3)": ["mean", "median", "var", "std", "sem"]})
summary_drug2_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
x_axis = clean_df['Drug Regimen'].unique()
y_axis = clean_df.groupby('Drug Regimen')['Timepoint'].count()
timepoints_per_drug_df = pd.DataFrame({'Drug Regimen': x_axis, 'Count': y_axis})
timepoints_per_drug_df.plot.bar(x='Drug Regimen', y='Count', rot=90, legend=False)
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Observed Mouse Timepoints')
plt.title('Timepoints for each Drug Regimen')
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
x_axis = clean_df['Drug Regimen'].unique()
y_axis = clean_df.groupby('Drug Regimen')['Timepoint'].count()
plt.bar(x_axis, y_axis)
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Observed Mouse Timepoints')
plt.title('Timepoints for each Drug Regimen')
plt.xticks(rotation=90)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
mice_pie_groupings = clean_df.groupby("Sex").count()["Mouse ID"]

mice_pie= pd.DataFrame({"Sex": mice_pie_groupings.index, \
                        "Percentage of Mice": mice_pie_groupings})

mice_pie.plot(kind="pie", \
              x="Sex", \
              y="Percentage of Mice", \
              title="Percentage of Mice by Sex", \
              xlabel="Sex",
              ylabel="Percentage of Mice",
            autopct='%1.1f%%'  ) 
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels = clean_df['Sex'].unique()
male_count = clean_df[clean_df['Sex']=='Male'].shape[0]
female_count = clean_df[clean_df['Sex']=='Female'].shape[0]
sizes = [female_count, male_count]
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Distribution of Male and Female')
plt.ylabel('Sex')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = clean_df.groupby('Mouse ID')['Timepoint'].max()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
tumor_volume = pd.merge(clean_df, last_timepoint, on=['Mouse ID','Timepoint'])
tumor_volume
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       b128         45           38.982878                 2    Capomulin
# 1       f932          0           45.000000                 0     Ketapril
# 2       g107         35           71.905117                 0     Ketapril
# 3       a457         10           49.783419                 0     Ketapril
# 4       c819         40           62.175705                 1     Ketapril
# ..       ...        ...                 ...               ...          ...
# 243     t565         45           34.455298                 0    Capomulin
# 244     i557         45           47.685963                 1    Capomulin
# 245     m957         45           33.329098                 1    Capomulin
# 246     f966         20           30.485985                 0    Capomulin
# 247     m601         45           28.430964                 1    Capomulin
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)

treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)

tumor_vol_data = []


# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for treatment in treatments:

    quartiles = clean_df[clean_df["Drug Regimen"] == treatment]["Tumor Volume (mm3)"].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    
    # Locate the rows which contain mice on each drug and get the tumor volumes

   
    # add subset 

    
    # Determine outliers using upper and lower bounds
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
capomulin_timepoints = clean_df[(clean_df["Mouse ID"] == "b128") & \
                                (clean_df["Drug Regimen"] == "Capomulin")]

plt.plot(capomulin_timepoints["Timepoint"], capomulin_timepoints["Tumor Volume (mm3)"])
plt.title("Tumor Volume in Mouse b128 with Capomulin")
plt.xlabel("Timepoint (Seconds)")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
weight_capomulin = clean_df[clean_df["Drug Regimen"] == "Capomulin"]\
                           .groupby("Mouse ID")\
                           .mean(["Weight (g)", "Tumor Volume (mm3)"])\
                           [["Weight (g)", "Tumor Volume (mm3)"]]


plt.scatter(weight_capomulin["Weight (g)"], weight_capomulin["Tumor Volume (mm3)"])
plt.title("Weight vs. Averaged Observed Tumor Value in Mice with Capomulin")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
correlation = round(st.pearsonr(weight_capomulin["Weight (g)"], weight_capomulin["Tumor Volume (mm3)"])[0], 2)

plt.scatter(weight_capomulin["Weight (g)"], weight_capomulin["Tumor Volume (mm3)"])
plt.title("Weight vs. Averaged Observed Tumor Value in Mice with Capomulin")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")

# linear Regression
x = weight_capomulin["Weight (g)"]
slope, line_int, r, p, se = st.linregress(weight_capomulin["Weight (g)"], weight_capomulin["Tumor Volume (mm3)"])
line_fit = slope * x + line_int

# Line Plot
plt.plot(x, line_fit, color="red")
plt.show

print("The correlation between weight and the averge tumor volume is " + str(correlation))
# Out:
# The correlation between weight and the averge tumor volume is 0.84
